# %% [markdown]
# # Which Asset Class is safe against unexpected inflation?

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from pandas.tseries.offsets import MonthEnd, YearEnd, YearBegin

import matplotlib.dates as mdates
import matplotlib.ticker as mtick

INFLATION_DATA = 'data/inflation.csv'
TBOND_DATA = 'data/10y_tbond.csv'
TIPS_DATA = 'data/10y_tips.csv'
SP500_DATA = 'data/sp500.xls'
GOLD_DATA = 'data/gold.xlsx'
REAL_ESTATE_DATA = 'data/real_estate.xls'

# %% [markdown]
# ## 1. Prepare Expected and Unexpected Inflation Rates

# %%
inf = pd.read_csv(INFLATION_DATA)
inf = inf.rename(columns={'Date': 'date', 'Value': 'actual_inflation'})
inf['date'] = pd.to_datetime(inf['date'])
inf.set_index('date', inplace=True)
inf['actual_inflation'] = inf['actual_inflation'] / 100

# %%
inf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1289 entries, 2021-05-31 to 1914-01-31
# Data columns (total 1 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   actual_inflation  1289 non-null   float64
# dtypes: float64(1)
# memory usage: 20.1 KB

# %%
plt.figure(figsize=(16, 6))
sns.set_theme()
sns.lineplot(data=inf, x=inf.index, y="actual_inflation");

# %%
inf.index
# Out:
# DatetimeIndex(['2021-05-31', '2021-04-30', '2021-03-31', '2021-02-28',
#                '2021-01-31', '2020-12-31', '2020-11-30', '2020-10-31',
#                '2020-09-30', '2020-08-31',
#                ...
#                '1914-10-31', '1914-09-30', '1914-08-31', '1914-07-31',
#                '1914-06-30', '1914-05-31', '1914-04-30', '1914-03-31',
#                '1914-02-28', '1914-01-31'],
#               dtype='datetime64[ns]', name='date', length=1289, freq=None)

# %%
inf = inf.sort_values(by='date')
inf['avg_past_10y'] = inf['actual_inflation'].rolling(120).mean()
inf['unexpected_inflation'] = inf['actual_inflation'] - inf['avg_past_10y']
inf = inf.dropna()
inf = inf.groupby(pd.Grouper(freq="Y")).last()
inf
# Out:
#             actual_inflation  avg_past_10y  unexpected_inflation
# date
# 1923-12-31           0.02367      0.061022             -0.037352
# 1924-12-31           0.00000      0.060125             -0.060125
# 1925-12-31           0.03468      0.061636             -0.026956
# 1926-12-31          -0.01117      0.054929             -0.066099
# 1927-12-31          -0.02260      0.035204             -0.057804
# ...                      ...           ...                   ...
# 2017-12-31           0.02109      0.016981              0.004109
# 2018-12-31           0.01910      0.015578              0.003522
# 2019-12-31           0.02285      0.017727              0.005123
# 2020-12-31           0.01362      0.017320             -0.003700
# 2021-12-31           0.04993      0.017461              0.032469
#
# [99 rows x 3 columns]

# %%
def plot_multilines(df, x, Y):
    df_plot = df.reset_index()[[x]+Y]
    df_plot[x] = df_plot[x] - YearBegin(1)
    df_plot = df_plot.melt(x, var_name='cols', value_name='vals')
    plt.figure(figsize=(16, 6))
    sns.set_theme()
    ax = sns.lineplot(x=x, y='vals', hue='cols', data=df_plot)
    return ax
    
ax = plot_multilines(inf, 'date', ['avg_past_10y', 'actual_inflation', 'unexpected_inflation'])

def style(ax, labels=None, year_gap=2):
    ax.xaxis.set_major_locator(mdates.YearLocator(year_gap))
    ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y"))
    ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
    ax.margins(x=0)
    ax.set(ylabel="value")
    ax.legend(title="")
    if labels != None:
        legend = ax.legend()
        for i, l in enumerate(labels):
            legend.texts[i].set_text(l)
    return plt.xticks(rotation=45)

ax = style(ax);

# %% [markdown]
# ## 2. T-Bond

# %%
tbond = pd.read_csv(TBOND_DATA)

def adjust_date_index(df, date='Date', price='Price'):
    def repl(m):
        return "20{}".format(m.group(0))
    
    df.loc[df[date].str[-2:].astype(int) <= 21, date] = \
        df[df[date].str[-2:].astype(int) <= 21][date].str.replace(r"..$",repl)
    
    def repl(m):
        return "19{}".format(m.group(0))
    
    df.loc[df[date].str[-2:].astype(int) > 21, date] = \
        df[df[date].str[-2:].astype(int) > 21][date].str.replace(r"..$",repl)
    
    df[date] = pd.to_datetime(df[date], format="%b %Y") + MonthEnd(1)
    return df

def get_yield_yoy(df):
    g = df.groupby(pd.Grouper(freq="Y"))
    firstp = g['price'].last().shift(1)
    lastp = g['price'].last()
    comb = firstp.to_frame(name='first') \
           .join(lastp.to_frame(name='last'))
    comb['yoy_change'] = (comb['last'] / comb['first']) - 1
    comb = comb.dropna()
    return comb

tbond = adjust_date_index(tbond)
tbond = tbond.rename(columns={'Date': 'date', 'Price': 'yield'})
tbond['yield'] = tbond['yield'] / 100
tbond = tbond.set_index('date')
tbond = get_yield_yoy(tbond)

# %%
tbond.head(5)
# Out:
#               yield   Open   High    Low Change %
# date
# 2021-06-30  0.01443  1.610  1.637  1.430   -8.69%
# 2021-05-31  0.01581  1.631  1.707  1.469   -2.78%
# 2021-04-30  0.01626  1.737  1.753  1.528   -6.77%
# 2021-03-31  0.01744  1.395  1.776  1.383   23.99%
# 2021-02-28  0.01407  1.071  1.614  1.060   31.38%

# %%
tbond.plot()

# %%
tbond
# Out:
#              first    last  yoy_change
# date
# 1971-12-31   6.390   5.930   -0.071987
# 1972-12-31   5.930   6.360    0.072513
# 1973-12-31   6.360   6.740    0.059748
# 1974-12-31   6.740   7.430    0.102374
# 1975-12-31   7.430   8.000    0.076716
# 1976-12-31   8.000   6.870   -0.141250
# 1977-12-31   6.870   7.690    0.119360
# 1978-12-31   7.690   9.010    0.171651
# 1979-12-31   9.010  10.390    0.153163
# 1980-12-31  10.390  12.411    0.194514
# 1981-12-31  12.411  13.960    0.124809
# 1982-12-31  13.960  10.319   -0.260817
# 1983-12-31  10.319  11.781    0.141680
# 1984-12-31  11.781  11.542   -0.020287
# 1985-12-31  11.542   8.987   -0.221365
# 1986-12-31   8.987   7.220   -0.196617
# 1987-12-31   7.220   8.834    0.223546
# 1988-12-31   8.834   9.145    0.035205
# 1989-12-31   9.145   7.933   -0.132531
# 1990-12-31   7.933   8.079    0.018404
# 1991-12-31   8.079   6.699   -0.170813
# 1992-12-31   6.699   6.690   -0.001343
# 1993-12-31   6.690   5.787   -0.134978
# 1994-12-31   5.787   7.831    0.353205
# 1995-12-31   7.831   5.575   -0.288086
# 1996-12-31   5.575   6.429    0.153184
# 1997-12-31   6.429   5.744   -0.106548
# 1998-12-31   5.744   4.658   -0.189067
# 1999-12-31   4.658   6.435    0.381494
# 2000-12-31   6.435   5.112   -0.205594
# 2001-12-31   5.112   5.029   -0.016236
# 2002-12-31   5.029   3.818   -0.240803
# 2003-12-31   3.818   4.253    0.113934
# 2004-12-31   4.253   4.222   -0.007289
# 2005-12-31   4.222   4.395    0.040976
# 2006-12-31   4.395   4.700    0.069397
# 2007-12-31   4.700   4.035   -0.141489
# 2008-12-31   4.035   2.220   -0.449814
# 2009-12-31   2.220   3.837    0.728378
# 2010-12-31   3.837   3.288   -0.143081
# 2011-12-31   3.288   1.876   -0.429440
# 2012-12-31   1.876   1.757   -0.063433
# 2013-12-31   1.757   3.026    0.722254
# 2014-12-31   3.026   2.170   -0.282882
# 2015-12-31   2.170   2.269    0.045622
# 2016-12-31   2.269   2.446    0.078008
# 2017-12-31   2.446   2.405   -0.016762
# 2018-12-31   2.405   2.686    0.116840
# 2019-12-31   2.686   1.919   -0.285555
# 2020-12-31   1.919   0.916   -0.522668
# 2021-12-31   0.916   1.443    0.575328

# %%
inf.head(5)
# Out:
#             actual_inflation  avg_past_10y  unexpected_inflation
# date
# 1923-12-31           0.02367      0.061022             -0.037352
# 1924-12-31           0.00000      0.060125             -0.060125
# 1925-12-31           0.03468      0.061636             -0.026956
# 1926-12-31          -0.01117      0.054929             -0.066099
# 1927-12-31          -0.02260      0.035204             -0.057804

# %%
combined1 = pd.merge(inf, tbond, left_on='date', right_on='date', how='left')
combined1 = combined1.rename(columns={'yoy_change': 'tbond'})
combined1 = combined1[['actual_inflation', 'unexpected_inflation', 'tbond']]

# %%
ax = plot_multilines(combined1, 'date', ['unexpected_inflation', 'tbond'])
style(ax, ["Unexpected Inflation", "T-Bond return"])
ax.set_title("Unexpected Inflation and T-Bond");

# %% [markdown]
# ## 3. S&P 500 Index

# %%
sp500 = pd.read_excel(SP500_DATA,
                      sheet_name="Data",
                      skiprows=list(range(0,7))
                      )
sp500 = sp500.iloc[:-1, :3]
sp500 = sp500.rename(columns={'Date': 'date', 'P': 'price', 'D': 'dividend'})

# 1871.1 to 1871.10
sp500['date'] = sp500['date'].apply(lambda x: '{0:.2f}'.format(x))

sp500['date'] = sp500['date'].astype(str)
sp500['price'] = sp500['price'].astype(float)
sp500['date'] = pd.to_datetime(sp500['date'], format="%Y.%m")
sp500['date'] = sp500['date'] + MonthEnd(1)
sp500.set_index('date', inplace=True)

# %%
def get_total_dividends(df):
    g = df.groupby(pd.Grouper(freq="Q-DEC"))
    g = g.last().groupby(pd.Grouper(freq="Y")).sum()
    g = g['dividend']
    return g

divs = get_total_dividends(sp500)
divs
# Out:
# date
# 1871-12-31      1.040000
# 1872-12-31      1.140000
# 1873-12-31      1.275000
# 1874-12-31      1.320000
# 1875-12-31      1.245000
#                  ...
# 2017-12-31    190.700000
# 2018-12-31    207.080000
# 2019-12-31    226.477275
# 2020-12-31    236.389450
# 2021-12-31     57.633387
# Freq: A-DEC, Name: dividend, Length: 151, dtype: float64

# %%
divs.shift(1)
# Out:
# date
# 1871-12-31           NaN
# 1872-12-31      1.040000
# 1873-12-31      1.140000
# 1874-12-31      1.275000
# 1875-12-31      1.320000
#                  ...
# 2017-12-31    179.070000
# 2018-12-31    190.700000
# 2019-12-31    207.080000
# 2020-12-31    226.477275
# 2021-12-31    236.389450
# Freq: A-DEC, Name: dividend, Length: 151, dtype: float64

# %%
sp500.groupby(pd.Grouper(freq="Y")).price.last()
# Out:
# date
# 1871-12-31       4.740000
# 1872-12-31       5.070000
# 1873-12-31       4.420000
# 1874-12-31       4.540000
# 1875-12-31       4.370000
#                  ...
# 2017-12-31    2664.340000
# 2018-12-31    2567.310000
# 2019-12-31    3176.749524
# 2020-12-31    3695.310000
# 2021-12-31    4208.120000
# Freq: A-DEC, Name: price, Length: 151, dtype: float64

# %%
def get_earnings_plus_dividends_yoy(df, dividends):
    g = df.groupby(pd.Grouper(freq="Y"))
    prev_dividends = dividends.shift(1)
    firstp = g.price.last().shift(1)
    firstp_div = firstp + prev_dividends
    lastp = g.price.last()
    lastp_div = lastp + dividends
    comb = firstp.to_frame(name='first') \
           .join(lastp.to_frame(name='last')) \
           .join(dividends.to_frame(name='dividends')) \
           .join(lastp_div.to_frame(name='last_plus_dividends'))
    comb['yoy_change'] = (comb['last_plus_dividends'] / comb['first']) - 1
#     comb['earnings'] = g.earnings_default.last()
    return comb
sp500g = get_earnings_plus_dividends_yoy(sp500, divs)
sp500g = sp500g[sp500g.index.year >= inf.index[0].year]
sp500g
# Out:
#                   first         last   dividends  last_plus_dividends  \
# date
# 1923-12-31     8.780000     8.550000    2.090000            10.640000
# 1924-12-31     8.550000    10.160000    2.170000            12.330000
# 1925-12-31    10.160000    12.460000    2.325000            14.785000
# 1926-12-31    12.460000    13.490000    2.625000            16.115000
# 1927-12-31    13.490000    17.460000    2.960000            20.420000
# ...                 ...          ...         ...                  ...
# 2017-12-31  2246.630000  2664.340000  190.700000          2855.040000
# 2018-12-31  2664.340000  2567.310000  207.080000          2774.390000
# 2019-12-31  2567.310000  3176.749524  226.477275          3403.226799
# 2020-12-31  3176.749524  3695.310000  236.389450          3931.699450
# 2021-12-31  3695.310000  4208.120000   57.633387          4265.753387
#
#             yoy_change
# date
# 1923-12-31    0.211845
# 1924-12-31    0.442105
# 1925-12-31    0.455217
# 1926-12-31    0.293339
# 1927-12-31    0.513714
# ...                ...
# 2017-12-31    0.270810
# 2018-12-31    0.041305
# 2019-12-31    0.325600
# 2020-12-31    0.237649
# 2021-12-31    0.154370
#
# [99 rows x 5 columns]

# %%
ax = plot_multilines(sp500g, 'date', ['yoy_change'])
style(ax);

# %% [markdown]
# ### Merging unexpected inflation + S&P 500 Index

# %%
combined2 = pd.merge(combined1, sp500g, left_on='date', right_on='date', how='left')
combined2 = combined2.rename(columns={'yoy_change': 'sp500'})
combined2 = combined2[['actual_inflation', 'unexpected_inflation', 'tbond', 'sp500']]

# %%
combined2
# Out:
#             actual_inflation  unexpected_inflation     tbond     sp500
# date
# 1923-12-31           0.02367             -0.037352       NaN  0.211845
# 1924-12-31           0.00000             -0.060125       NaN  0.442105
# 1925-12-31           0.03468             -0.026956       NaN  0.455217
# 1926-12-31          -0.01117             -0.066099       NaN  0.293339
# 1927-12-31          -0.02260             -0.057804       NaN  0.513714
# ...                      ...                   ...       ...       ...
# 2017-12-31           0.02109              0.004109 -0.016762  0.270810
# 2018-12-31           0.01910              0.003522  0.116840  0.041305
# 2019-12-31           0.02285              0.005123 -0.285555  0.325600
# 2020-12-31           0.01362             -0.003700 -0.522668  0.237649
# 2021-12-31           0.04993              0.032469  0.575328  0.154370
#
# [99 rows x 4 columns]

# %%
ax = plot_multilines(combined2, 'date', ['unexpected_inflation', 'tbond', 'sp500'])
style(ax, ["Unexpected Inflation", "T-Bond", "S&P500 return (+ dividends)"])
ax.set_title("Unexpected Inflation, T-Bond, and S&P 500");

# %% [markdown]
# ## 4. Gold

# %%
gold = pd.read_excel(GOLD_DATA,
                     sheet_name="Annual_EndofPeriod",
                     skiprows=list(range(0,9)),
                     header=None,
                     engine="openpyxl")
gold = gold.iloc[:, 3:5]
gold = gold.rename(columns={3: 'date', 4: 'price'})
gold['date'] = pd.to_datetime(gold['date'], format='%Y') + YearEnd(1)
gold = gold.set_index('date')
gold['firstp'] = gold['price'].shift(1)
gold['yoy_change'] = (gold['price'] / gold['firstp']) - 1

# %%
gold.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 43 entries, 1978-12-31 to 2020-12-31
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   price       43 non-null     float64
#  1   firstp      42 non-null     float64
#  2   yoy_change  42 non-null     float64
# dtypes: float64(3)
# memory usage: 1.3 KB

# %%
gold.head(5)
# Out:
#              price  firstp  yoy_change
# date
# 1978-12-31  226.00     NaN         NaN
# 1979-12-31  512.00  226.00    1.265487
# 1980-12-31  589.75  512.00    0.151855
# 1981-12-31  397.50  589.75   -0.325986
# 1982-12-31  456.90  397.50    0.149434

# %%
combined3 = pd.merge(combined2, gold, left_on='date', right_on='date', how='left')
combined3 = combined3.rename(columns={'yoy_change': 'gold'})
combined3 = combined3[['actual_inflation', 'unexpected_inflation', 'tbond', 'sp500', 'gold']]

# %%
combined3
# Out:
#             actual_inflation  unexpected_inflation     tbond     sp500  \
# date
# 1923-12-31           0.02367             -0.037352       NaN  0.211845
# 1924-12-31           0.00000             -0.060125       NaN  0.442105
# 1925-12-31           0.03468             -0.026956       NaN  0.455217
# 1926-12-31          -0.01117             -0.066099       NaN  0.293339
# 1927-12-31          -0.02260             -0.057804       NaN  0.513714
# ...                      ...                   ...       ...       ...
# 2017-12-31           0.02109              0.004109 -0.016762  0.270810
# 2018-12-31           0.01910              0.003522  0.116840  0.041305
# 2019-12-31           0.02285              0.005123 -0.285555  0.325600
# 2020-12-31           0.01362             -0.003700 -0.522668  0.237649
# 2021-12-31           0.04993              0.032469  0.575328  0.154370
#
#                 gold
# date
# 1923-12-31       NaN
# 1924-12-31       NaN
# 1925-12-31       NaN
# 1926-12-31       NaN
# 1927-12-31       NaN
# ...              ...
# 2017-12-31  0.126625
# 2018-12-31 -0.009295
# 2019-12-31  0.184324
# 2020-12-31  0.246146
# 2021-12-31       NaN
#
# [99 rows x 5 columns]

# %%
ax = plot_multilines(combined3, 'date', ['unexpected_inflation', 'tbond', 'sp500', 'gold'])
style(ax, ["Unexpected Inflation", "T-Bond", "S&P500 (+dividends)", "Gold"])
ax.set_title("Unexpected Inflation, T-Bond, S&P 500, and Gold");

# %% [markdown]
# ## 5. Real Estate

# %%
real_estate = pd.read_excel(REAL_ESTATE_DATA,
                            sheet_name="Data",
                            skiprows=list(range(0,6)),
                            engine="xlrd")
real_estate = real_estate.rename(columns={'Date': 'year', 'Index': 'index'})
real_estate = real_estate[['year', 'index']]
real_estate = real_estate.dropna()

def impute_values(df, id_field, value_field):
    """ Impute missing values in `df` by looking at id differences.
    
    
    """
    real_estate.loc[real_estate[id_field] % 1 == 0, id_field] = \
        real_estate.loc[real_estate[id_field] % 1 == 0, id_field] + 1
    
    indexes = pd.Index(np.arange(df[id_field].min(), df[id_field].max(), 1))
    df1 = df.set_index(id_field)
    missing_indexes = indexes.difference(df1.index)
    for idx in missing_indexes:
        df1.loc[idx, value_field] = None
    df1 = df1.sort_index()
    df1[value_field] = df1[value_field].interpolate(method='linear')
    df1 = df1.loc[df1.index % 1 == 0].shift(-1)
    return df1

real_estate = impute_values(real_estate, 'year', 'index')

real_estate['date'] = pd.to_datetime(real_estate.index.astype(int), format="%Y") + YearEnd(1)
print(real_estate.iloc[54:59])
print(real_estate.iloc[116:122])
real_estate = real_estate.set_index('date')
real_estate['prev_index'] = real_estate['index'].shift(1)
real_estate['yoy_change'] = real_estate['index'] / real_estate['prev_index'] - 1
real_estate = real_estate.dropna()
real_estate['yoy_change'] = real_estate['yoy_change'].astype(float)
print(real_estate.iloc[53:58])
print(real_estate.iloc[115:121])
# Out:
#              index       date
# year
# 1945.0   87.750046 1945-12-31
# 1946.0  106.505896 1946-12-31
# 1947.0  109.329671 1947-12-31
# 1948.0  101.222580 1948-12-31
# 1949.0  100.046608 1949-12-31
#              index       date
# year
# 2007.0  175.006917 2007-12-31
# 2008.0  153.309586 2008-12-31
# 2009.0  144.255863 2009-12-31
# 2010.0  136.191822 2010-12-31
# 2011.0  127.405198 2011-12-31
# 2012.0  134.084074 2012-12-31
#                  index  prev_index  yoy_change
# date
# 1945-12-31   87.750046   80.308996    0.092655
# 1946-12-31  106.505896   87.750046    0.213742
# 1947-12-31  109.329671  106.505896    0.026513
# 1948-12-31  101.222580  109.329671   -0.074153
# 1949-12-31  100.046608  101.222580   -0.011618
#                  index  prev_index  yoy_change
# date
# 2007-12-31  175.006917  193.717583   -0.096587
# 2008-12-31  153.309586  175.006917   -0.123980
# 2009-12-31  144.255863  153.309586   -0.059055
# 2010-12-31  136.191822  144.255863   -0.055901
# 2011-12-31  127.405198  136.191822   -0.064517
# 2012-12-31  134.084074  127.405198    0.052422

# %%
combined4 = pd.merge(combined3, real_estate, left_on='date', right_on='date')
combined4 = combined4.rename(columns={'yoy_change': 'real_estate'})
combined4 = combined4[['actual_inflation', 'unexpected_inflation', 'tbond', 'sp500', 'gold', 'real_estate']]

# %%
combined4
# Out:
#             actual_inflation  unexpected_inflation     tbond     sp500  \
# date
# 1923-12-31           0.02367             -0.037352       NaN  0.211845
# 1924-12-31           0.00000             -0.060125       NaN  0.442105
# 1925-12-31           0.03468             -0.026956       NaN  0.455217
# 1926-12-31          -0.01117             -0.066099       NaN  0.293339
# 1927-12-31          -0.02260             -0.057804       NaN  0.513714
# ...                      ...                   ...       ...       ...
# 2016-12-31           0.02075              0.003047  0.078008  0.180918
# 2017-12-31           0.02109              0.004109 -0.016762  0.270810
# 2018-12-31           0.01910              0.003522  0.116840  0.041305
# 2019-12-31           0.02285              0.005123 -0.285555  0.325600
# 2020-12-31           0.01362             -0.003700 -0.522668  0.237649
#
#                 gold  real_estate
# date
# 1923-12-31       NaN     0.020775
# 1924-12-31       NaN    -0.027022
# 1925-12-31       NaN     0.052174
# 1926-12-31       NaN    -0.072569
# 1927-12-31       NaN    -0.015316
# ...              ...          ...
# 2016-12-31  0.081038     0.030513
# 2017-12-31  0.126625     0.040372
# 2018-12-31 -0.009295     0.025609
# 2019-12-31  0.184324     0.014301
# 2020-12-31  0.246146     0.099125
#
# [98 rows x 6 columns]

# %%
ax = plot_multilines(combined4, 'date', ['unexpected_inflation', 'real_estate'])
style(ax, ["Unexpected Inflation", "Real Estate"])
ax.set_title("Unexpected Inflation and Real Estate");

# %%
corr = combined4[['actual_inflation', 'unexpected_inflation', 'tbond', 'sp500', 'gold', 'real_estate']].corr()
corr
# Out:
#                       actual_inflation  unexpected_inflation     tbond  \
# actual_inflation              1.000000              0.758241  0.263981
# unexpected_inflation          0.758241              1.000000  0.244875
# tbond                         0.263981              0.244875  1.000000
# sp500                        -0.005683             -0.153249  0.156903
# gold                          0.390833              0.494028 -0.062211
# real_estate                   0.097346              0.118188  0.084303
#
#                          sp500      gold  real_estate
# actual_inflation     -0.005683  0.390833     0.097346
# unexpected_inflation -0.153249  0.494028     0.118188
# tbond                 0.156903 -0.062211     0.084303
# sp500                 1.000000  0.040701     0.134909
# gold                  0.040701  1.000000    -0.070456
# real_estate           0.134909 -0.070456     1.000000

# %%
sns.set_theme(style="white")
mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(20, 230, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5},
            annot=True);
